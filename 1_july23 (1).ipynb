# %%
1.What is the primary goal of Object-Oriented Programming (OOP)?

ans- It is the basic concept of object-oriented programming that helps programmers to bind the data and functions together that manipulate the data.
The goal of oops is 1. Speed 2. Reuse 3. User - interface 4.provide the security of code using encapsulation
#oops pillers - 1.encapsulation   2.polymorphism  3.inheritances   4.abstraction

# %%
2. What is an object in Python?

ans- object is an instances of the class. or specific entity of the class.
example- suppose we creat a class name Animal and then we creat object dog, cat etc.......so the dog,cat is object of class animal

# %%
3.What is a class in Python?
ans- in python class is a blueprint of an object.
eg- map of the house is the blueprint of house. so map is a class
class person:   #class in pythhon
    def __init__ (self,name,last_name):
        self.name=name
        self.last_name=last_name
        print(f"the name is {self.name} and last name is {self.last_name}")
person=person("harshit","agrawal")

# %%
4.What are attributes and methods in a class?
ans-Class Attributes are the attributes that belong to the class
itself rather than a particular object. Usually, we use class attributes to define the attributes that have
a common value among all the objects inside the class. Class Methods are the methods that have access to the 
class attributes
class car:
    def __init__ (self,brand,model,color):   #attributes
        self.brand=brand
        self.model=model
        self.color=color
    def start_engine(self):
        print(f"the car of {self.brand},{self.model} and {self.color} is starting")

# %%
5.What is the difference between class variables and instance variables in Python?
ans-#class variables
class variables are variables that are shared by aall instances of a class. they are defined within the class. class variables are associated with the class itself rather than with specific entity.
class person:
    company_name="ineuron" #class variables
    def __init__ (self,name1,lastname):
        self.name=name1
        self.last_name=lastname
#instances variables
Variables that are owned by the class instances are known as instance variables.
This statement implies that for every instance or object of a class, the instance variables are unlike.
instance variables are defined within the functions.
class Student:  
    # using the initializing function  
    def __init__(self, id, name, age):  
        self.id = id  
        self.name = name  
        self.age = age  
  
#  instantiating the class  
dBase = Student(102, "Sam", 13)  
# printing the required values  
print("Roll Number of the Student:", dBase.id)  
print("Name of the Student:", dBase.name)  
print("Age of the Student:", dBase.age) 
explanation-we have defined a Student class and defined some variables as id, name, and age passed as arguments within
the constructor method. We have then instantiated the class and print the values of the instance variables for the users.
As a result, we will obtain a made-up of the values of the variables initialized for the Instance of dBase.
Instance variables, owned by the class objects, enable the developers to store different values in each instance
assigned to those variables.

# %%
6.What is the purpose of the self parameter in Python class methods?
answer-The self parameter is a reference to the current instance of the class, and is used to access variables that 
belongs to the class.
class car:
    def __init__ (self,brand,model,color): #current instance of the class
        self.brand=brand #accesss variables to the class
        self.model=model
        self.color=color
    def start_engine(self):
        print(f"the car of {self.brand},{self.model} and {self.color} is starting")

# %%
#Question07
class Book:
    def __init__(self, title, author, isbn, publication_year, available_copies):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies

    def check_out(self):
        if self.available_copies > 0:
            self.available_copies -= 1
            print(f"Book '{self.title}' checked out. Available copies: {self.available_copies}")
        else:
            print(f"Book '{self.title}' is not available for checkout.")

    def return_book(self):
        self.available_copies += 1
        print(f"Book '{self.title}' returned. Available copies: {self.available_copies}")

    def display_book_info(self):
        print("Book Information:")
        print(f"Title: {self.title}")
        print(f"Author(s): {self.author}")
        print(f"ISBN: {self.isbn}")
        print(f"Publication Year: {self.publication_year}")
        print(f"Available Copies: {self.available_copies}")

# Example usage
book1 = Book("Sample Book 1", "John Doe", "1234567890", 2023, 5)
book1.display_book_info()

print("\nChecking out book:")
book1.check_out()

print("\nReturning book:")
book1.return_book()

print("\nChecking out again:")
book1.check_out()
# Out:
# Book Information:
# Title: Sample Book 1
# Author(s): John Doe
# ISBN: 1234567890
# Publication Year: 2023
# Available Copies: 5
#
# Checking out book:
# Book 'Sample Book 1' checked out. Available copies: 4
#
# Returning book:
# Book 'Sample Book 1' returned. Available copies: 5
#
# Checking out again:
# Book 'Sample Book 1' checked out. Available copies: 4

# %%
#question08
class Ticket:
    def __init__(self, ticket_id, event_name, event_date, venue, seat_number, price):
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = False

    def reserve_ticket(self):
        if not self.is_reserved:
            self.is_reserved = True
            print(f"Ticket {self.ticket_id} has been reserved.")

    def cancel_reservation(self):
        if self.is_reserved:
            self.is_reserved = False
            print(f"Reservation for ticket {self.ticket_id} has been canceled.")

    def display_ticket_info(self):
        print("Ticket Information:")
        print(f"Ticket ID: {self.ticket_id}")
        print(f"Event Name: {self.event_name}")
        print(f"Event Date: {self.event_date}")
        print(f"Venue: {self.venue}")
        print(f"Seat Number: {self.seat_number}")
        print(f"Price: ${self.price:.2f}")
        print(f"Reservation Status: {'Reserved' if self.is_reserved else 'Not Reserved'}")

# Example usage
ticket1 = Ticket(1, "Concert", "2023-08-25", "Music Hall", "A12", 50.00)
ticket1.display_ticket_info()

print()

ticket2 = Ticket(2, "Sports Game", "2023-09-05", "Stadium", "B23", 75.00)
ticket2.reserve_ticket()
ticket2.display_ticket_info()

print()

ticket3 = Ticket(3, "Theater Play", "2023-08-30", "Theater Royale", "C8", 40.00)
ticket3.reserve_ticket()
ticket3.cancel_reservation()
ticket3.display_ticket_info()
# Out:
# Ticket Information:
# Ticket ID: 1
# Event Name: Concert
# Event Date: 2023-08-25
# Venue: Music Hall
# Seat Number: A12
# Price: $50.00
# Reservation Status: Not Reserved
#
# Ticket 2 has been reserved.
# Ticket Information:
# Ticket ID: 2
# Event Name: Sports Game
# Event Date: 2023-09-05
# Venue: Stadium
# Seat Number: B23
# Price: $75.00
# Reservation Status: Reserved
#
# Ticket 3 has been reserved.
# Reservation for ticket 3 has been canceled.
# Ticket Information:
# Ticket ID: 3
# Event Name: Theater Play
# Event Date: 2023-08-30
# Venue: Theater Royale
# Seat Number: C8
# Price: $40.00
# Reservation Status: Not Reserved

# %%
#question09
class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)
        print(f"{item.name} added to the cart.")

    def remove_item(self, item):
        if item in self.items:
            self.items.remove(item)
            print(f"{item.name} removed from the cart.")
        else:
            print(f"{item.name} is not in the cart.")

    def calculate_total(self):
        total = sum(item.price for item in self.items)
        return total

    def view_cart(self):
        if not self.items:
            print("Your cart is empty.")
        else:
            print("Items in your cart:")
            for item in self.items:
                print(f"{item.name} - ${item.price:.2f}")

# Example Item class for illustration
class Item:
    def __init__(self, name, price):
        self.name = name
        self.price = price

# Example usage
item1 = Item("Laptop", 1000.00)
item2 = Item("Headphones", 150.00)
item3 = Item("Mouse", 20.00)

cart = ShoppingCart()
cart.add_item(item1)
cart.add_item(item2)
cart.view_cart()

cart.remove_item(item2)
cart.view_cart()

cart.add_item(item3)
print(f"Total: ${cart.calculate_total():.2f}")
# Out:
# Laptop added to the cart.
# Headphones added to the cart.
# Items in your cart:
# Laptop - $1000.00
# Headphones - $150.00
# Headphones removed from the cart.
# Items in your cart:
# Laptop - $1000.00
# Mouse added to the cart.
# Total: $1020.00
